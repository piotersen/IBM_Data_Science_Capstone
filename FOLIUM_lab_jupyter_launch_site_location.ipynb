# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Hands-on Lab: Interactive Visual Analytics with Folium**

# %% [markdown]
# Estimated time needed: **40** minutes

# %% [markdown]
# The launch success rate may depend on many factors such as payload mass, orbit type, and so on. It may also depend on the location and proximities of a launch site, i.e., the initial position of rocket trajectories. Finding an optimal location for building a launch site certainly involves many factors and hopefully we could discover some of the factors by analyzing the existing launch site locations.

# %% [markdown]
# In the previous exploratory data analysis labs, you have visualized the SpaceX launch dataset using `matplotlib` and `seaborn` and discovered some preliminary correlations between the launch site and success rates. In this lab, you will be performing more interactive visual analytics using `Folium`.

# %% [markdown]
# ## Objectives

# %% [markdown]
# This lab contains the following tasks:
#
# *   **TASK 1:** Mark all launch sites on a map
# *   **TASK 2:** Mark the success/failed launches for each site on the map
# *   **TASK 3:** Calculate the distances between a launch site to its proximities
#
# After completed the above tasks, you should be able to find some geographical patterns about launch sites.

# %% [markdown]
# Let's first import required Python packages for this lab:

# %%
import piplite
await piplite.install(['folium'])
await piplite.install(['pandas'])

# %%
import folium
import pandas as pd

# %%
# Import folium MarkerCluster plugin
from folium.plugins import MarkerCluster
# Import folium MousePosition plugin
from folium.plugins import MousePosition
# Import folium DivIcon plugin
from folium.features import DivIcon

# %% [markdown]
# If you need to refresh your memory about folium, you may download and refer to this previous folium lab:

# %% [markdown]
# [Generating Maps with Python](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/labs/v4/DV0101EN-Exercise-Generating-Maps-in-Python.ipynb)

# %%
## Task 1: Mark all launch sites on a map
# Create a DataFrame with the unique launch sites and their coordinates
launch_sites = pd.DataFrame({
    "LaunchSite": ["CCAFS LC-40", "KSC LC-39A", "VAFB SLC-4E", "CCAFS SLC-40"],
    "Latitude": [28.5623, 28.5733, 34.6321, 28.5618],
    "Longitude": [-80.5774, -80.6043, -120.6108, -80.5774]
})

# Create a Folium map centered around the launch sites
launch_map = folium.Map(location=[28.5, -100], zoom_start=4)

# Add markers for each launch site
for _, row in launch_sites.iterrows():
    folium.Marker(
        location=[row["Latitude"], row["Longitude"]],
        popup=row["LaunchSite"],
        icon=folium.Icon(color="blue", icon="rocket")
    ).add_to(launch_map)

# Display the map
launch_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4fcee829b3f1db739543dee8c82253a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4fcee829b3f1db739543dee8c82253a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4fcee829b3f1db739543dee8c82253a0 = L.map(
#                 &quot;map_4fcee829b3f1db739543dee8c82253a0&quot;,
#                 {
#                     center: [28.5, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d266b5395e66d751ea5759108a70736 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0d266b5395e66d751ea5759108a70736.addTo(map_4fcee829b3f1db739543dee8c82253a0);
#
#
#             var marker_1486c7dcd6f79bf207c2a668c785e41f = L.marker(
#                 [28.5623, -80.5774],
#                 {
# }
#             ).addTo(map_4fcee829b3f1db739543dee8c82253a0);
#
#
#             var icon_4f390a856c2b9a1fcefe424c2e5da8b6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_1486c7dcd6f79bf207c2a668c785e41f.setIcon(icon_4f390a856c2b9a1fcefe424c2e5da8b6);
#
#
#         var popup_4c71c6037a219edf71826ea3edc1c5f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ca9dc59128c4d87eb03b4d4de97139d = $(`&lt;div id=&quot;html_2ca9dc59128c4d87eb03b4d4de97139d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_4c71c6037a219edf71826ea3edc1c5f4.setContent(html_2ca9dc59128c4d87eb03b4d4de97139d);
#
#
#
#         marker_1486c7dcd6f79bf207c2a668c785e41f.bindPopup(popup_4c71c6037a219edf71826ea3edc1c5f4)
#         ;
#
#
#
#
#             var marker_957b23e07ea73827f0610d7ab28af140 = L.marker(
#                 [28.5733, -80.6043],
#                 {
# }
#             ).addTo(map_4fcee829b3f1db739543dee8c82253a0);
#
#
#             var icon_2f992a00ad29a6c064f57ea3b06df7cb = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_957b23e07ea73827f0610d7ab28af140.setIcon(icon_2f992a00ad29a6c064f57ea3b06df7cb);
#
#
#         var popup_8359767db87a2dc6adc009db9bf6999b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_66a2a0a2a8b48806afb10c1122d17256 = $(`&lt;div id=&quot;html_66a2a0a2a8b48806afb10c1122d17256&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KSC LC-39A&lt;/div&gt;`)[0];
#                 popup_8359767db87a2dc6adc009db9bf6999b.setContent(html_66a2a0a2a8b48806afb10c1122d17256);
#
#
#
#         marker_957b23e07ea73827f0610d7ab28af140.bindPopup(popup_8359767db87a2dc6adc009db9bf6999b)
#         ;
#
#
#
#
#             var marker_2af53791d8970f79c197528adb18751c = L.marker(
#                 [34.6321, -120.6108],
#                 {
# }
#             ).addTo(map_4fcee829b3f1db739543dee8c82253a0);
#
#
#             var icon_62ac410815e8a19fbba47ac71fbb7df9 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_2af53791d8970f79c197528adb18751c.setIcon(icon_62ac410815e8a19fbba47ac71fbb7df9);
#
#
#         var popup_95f5770f3f2dad6f47fcc555bbd5d3a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4b9c796525d06c1090f52ad59e01c05 = $(`&lt;div id=&quot;html_d4b9c796525d06c1090f52ad59e01c05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VAFB SLC-4E&lt;/div&gt;`)[0];
#                 popup_95f5770f3f2dad6f47fcc555bbd5d3a8.setContent(html_d4b9c796525d06c1090f52ad59e01c05);
#
#
#
#         marker_2af53791d8970f79c197528adb18751c.bindPopup(popup_95f5770f3f2dad6f47fcc555bbd5d3a8)
#         ;
#
#
#
#
#             var marker_7fa89f166156c324f84d442dbc1a1b6c = L.marker(
#                 [28.5618, -80.5774],
#                 {
# }
#             ).addTo(map_4fcee829b3f1db739543dee8c82253a0);
#
#
#             var icon_bb1c5e006f785b8a201524e4ce975862 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&q

# %% [markdown]
# First, let's try to add each site's location on a map using site's latitude and longitude coordinates

# %% [markdown]
# The following dataset with the name `spacex_launch_geo.csv` is an augmented dataset with latitude and longitude added for each site.

# %%
# Download and read the `spacex_launch_geo.csv`
from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv'
resp = await fetch(URL)
spacex_csv_file = io.BytesIO((await resp.arrayBuffer()).to_py())
spacex_df=pd.read_csv(spacex_csv_file)

# %% [markdown]
# Now, you can take a look at what are the coordinates for each site.

# %%
# Select relevant sub-columns: `Launch Site`, `Lat(Latitude)`, `Long(Longitude)`, `class`
spacex_df = spacex_df[['Launch Site', 'Lat', 'Long', 'class']]
launch_sites_df = spacex_df.groupby(['Launch Site'], as_index=False).first()
launch_sites_df = launch_sites_df[['Launch Site', 'Lat', 'Long']]
launch_sites_df
# Out:
#     Launch Site        Lat        Long
# 0   CCAFS LC-40  28.562302  -80.577356
# 1  CCAFS SLC-40  28.563197  -80.576820
# 2    KSC LC-39A  28.573255  -80.646895
# 3   VAFB SLC-4E  34.632834 -120.610745

# %% [markdown]
# Above coordinates are just plain numbers that can not give you any intuitive insights about where are those launch sites. If you are very good at geography, you can interpret those numbers directly in your mind. If not, that's fine too. Let's visualize those locations by pinning them on a map.

# %% [markdown]
# We first need to create a folium `Map` object, with an initial center location to be NASA Johnson Space Center at Houston, Texas.

# %%
# Start location is NASA Johnson Space Center
nasa_coordinate = [29.559684888503615, -95.0830971930759]
site_map = folium.Map(location=nasa_coordinate, zoom_start=10)

# %% [markdown]
# We could use `folium.Circle` to add a highlighted circle area with a text label on a specific coordinate. For example,

# %%
# Create a blue circle at NASA Johnson Space Center's coordinate with a popup label showing its name
circle = folium.Circle(nasa_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
# Create a blue circle at NASA Johnson Space Center's coordinate with a icon showing its name
marker = folium.map.Marker(
    nasa_coordinate,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e957728e1925ebdfa8b2c5c87ee2e1e0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e957728e1925ebdfa8b2c5c87ee2e1e0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e957728e1925ebdfa8b2c5c87ee2e1e0 = L.map(
#                 &quot;map_e957728e1925ebdfa8b2c5c87ee2e1e0&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_96c2f5aa526f00fec721981c5e46ceb2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_96c2f5aa526f00fec721981c5e46ceb2.addTo(map_e957728e1925ebdfa8b2c5c87ee2e1e0);
#
#
#             var circle_43b04d37d0246d9d00355e28255f816c = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e957728e1925ebdfa8b2c5c87ee2e1e0);
#
#
#         var popup_7d2dd6fb5f8c8459da2edd06a05557fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84cdbe8b8e31440cc40c2056242fbd1f = $(`&lt;div id=&quot;html_84cdbe8b8e31440cc40c2056242fbd1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_7d2dd6fb5f8c8459da2edd06a05557fd.setContent(html_84cdbe8b8e31440cc40c2056242fbd1f);
#
#
#
#         circle_43b04d37d0246d9d00355e28255f816c.bindPopup(popup_7d2dd6fb5f8c8459da2edd06a05557fd)
#         ;
#
#
#
#
#             var marker_4d63ec4ee1f0bed8cc0a2551ee511363 = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {
# }
#             ).addTo(map_e957728e1925ebdfa8b2c5c87ee2e1e0);
#
#
#             var div_icon_9b5d9e92d3211b2c69e5ca574991ac60 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_4d63ec4ee1f0bed8cc0a2551ee511363.setIcon(div_icon_9b5d9e92d3211b2c69e5ca574991ac60);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# and you should find a small yellow circle near the city of Houston and you can zoom-in to see a larger circle.

# %% [markdown]
# Now, let's add a circle for each launch site in data frame `launch_sites`

# %% [markdown]
# *TODO:*  Create and add `folium.Circle` and `folium.Marker` for each launch site on the site map

# %% [markdown]
# An example of folium.Circle:

# %% [markdown]
# `folium.Circle(coordinate, radius=1000, color='#000000', fill=True).add_child(folium.Popup(...))`

# %% [markdown]
# An example of folium.Marker:

# %% [markdown]
# `folium.map.Marker(coordinate, icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0), html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'label', ))`

# %%
# Initial the map
site_map = folium.Map(location=nasa_coordinate, zoom_start=5)
# For each launch site, add a Circle object based on its coordinate (Lat, Long) values. In addition, add Launch site name as a popup label
# Create a Folium map centered around the launch sites
launch_map = folium.Map(location=[28.5, -100], zoom_start=4)

# Add markers and circles for each launch site
for _, row in launch_sites.iterrows():
    # Add a circle around the launch site
    folium.Circle(
        location=[row["Latitude"], row["Longitude"]],
        radius=50000,  # 50 km radius for visualization
        color="blue",
        fill=True,
        fill_color="lightblue",
        fill_opacity=0.5
    ).add_to(launch_map)
    
    # Add a marker with a popup label
    folium.Marker(
        location=[row["Latitude"], row["Longitude"]],
        popup=row["LaunchSite"],
        icon=folium.Icon(color="blue", icon="rocket")
    ).add_to(launch_map)

# Display the map
launch_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9413dca4ffd168598600b98e6922937f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9413dca4ffd168598600b98e6922937f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9413dca4ffd168598600b98e6922937f = L.map(
#                 &quot;map_9413dca4ffd168598600b98e6922937f&quot;,
#                 {
#                     center: [28.5, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1d11031778e3bc5ed61c5c1b21048430 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1d11031778e3bc5ed61c5c1b21048430.addTo(map_9413dca4ffd168598600b98e6922937f);
#
#
#             var circle_b8cb0329d1818524f2ff0db62ceffe18 = L.circle(
#                 [28.5623, -80.5774],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;lightblue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9413dca4ffd168598600b98e6922937f);
#
#
#             var marker_ad1346145a6dc600b6baaaef098a6bcf = L.marker(
#                 [28.5623, -80.5774],
#                 {
# }
#             ).addTo(map_9413dca4ffd168598600b98e6922937f);
#
#
#             var icon_ff7c4d876546e5143f5201401bd70bd9 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_ad1346145a6dc600b6baaaef098a6bcf.setIcon(icon_ff7c4d876546e5143f5201401bd70bd9);
#
#
#         var popup_424276ec878e5660605dc8a5f07e4e19 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30f2e557fa7f9625c07cf8c2f57b9ff3 = $(`&lt;div id=&quot;html_30f2e557fa7f9625c07cf8c2f57b9ff3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_424276ec878e5660605dc8a5f07e4e19.setContent(html_30f2e557fa7f9625c07cf8c2f57b9ff3);
#
#
#
#         marker_ad1346145a6dc600b6baaaef098a6bcf.bindPopup(popup_424276ec878e5660605dc8a5f07e4e19)
#         ;
#
#
#
#
#             var circle_20dc9af21f796b4307a2e70024fcc40f = L.circle(
#                 [28.5733, -80.6043],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;lightblue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9413dca4ffd168598600b98e6922937f);
#
#
#             var marker_1faa22e25bb4ac6bd63e2c4a9ae46c02 = L.marker(
#                 [28.5733, -80.6043],
#                 {
# }
#             ).addTo(map_9413dca4ffd168598600b98e6922937f);
#
#
#             var icon_8dce5d00168652b10227c6b76ef7aff2 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_1faa22e25bb4ac6bd63e2c4a9ae46c02.setIcon(icon_8dce5d00168652b10227c6b76ef7aff2);
#
#
#         var popup_4d8f7ac5ee63ffefbb0a2ea478ea8b20 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_692b50f9a2bec8552881035ea25f92c7 = $(`&lt;div id=&quot;html_692b50f9a2bec8552881035ea25f92c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KSC LC-39A&lt;/div&gt;`)[0];
#                 popup_4d8f7ac5ee63ffefbb0a2ea478ea8b20.setContent(html_692b50f9a2bec8552881035ea25f92c7);
#
#
#
#         marker_1faa22e25bb4ac6bd63e2c4a9ae46c02.bindPopup(popup_4d8f7ac5ee63ffefbb0a2ea478ea8b20)
#         ;
#
#
#
#
#             var circle_a31c325648c0539c08d5c963b0a1eee1 = L.circle(
#                 [34.6321, -120.6108],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;ligh

# %% [markdown]
# The generated map with marked launch sites should look similar to the following:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_markers.png">
# </center>

# %% [markdown]
# Now, you can explore the map by zoom-in/out the marked areas
# , and try to answer the following questions:
#
# *   Are all launch sites in proximity to the Equator line?
# *   Are all launch sites in very close proximity to the coast?
#
# Also please try to explain your findings.

# %%
# Task 2: Mark the success/failed launches for each site on the map
# Create a DataFrame with the provided SpaceX launch data
spacex_df = pd.DataFrame({
    "Launch Site": [
        "KSC LC-39A", "KSC LC-39A", "KSC LC-39A", 
        "CCAFS SLC-40", "CCAFS SLC-40", "CCAFS SLC-40", "CCAFS SLC-40",
        "CCAFS SLC-40", "CCAFS SLC-40", "CCAFS SLC-40"
    ],
    "Lat": [
        28.573255, 28.573255, 28.573255, 
        28.563197, 28.563197, 28.563197, 28.563197,
        28.563197, 28.563197, 28.563197
    ],
    "Long": [
        -80.646895, -80.646895, -80.646895, 
        -80.576820, -80.576820, -80.576820, -80.576820,
        -80.576820, -80.576820, -80.576820
    ],
    "Class": [1, 1, 1, 1, 1, 0, 0, 0, 1, 0]  # 1 = Success, 0 = Failure
})

# Define marker colors for success (green) and failure (red)
def get_marker_color(launch_status):
    return "green" if launch_status == 1 else "red"

# Create a Folium map centered around the launch sites
launch_map = folium.Map(location=[28.57, -80.6], zoom_start=6)

# Add markers for each launch with success (green) or failure (red)
for _, row in spacex_df.iterrows():
    folium.Marker(
        location=[row["Lat"], row["Long"]],
        popup=f"Launch Site: {row['Launch Site']}<br>Outcome: {'Success' if row['Class'] == 1 else 'Failure'}",
        icon=folium.Icon(color=get_marker_color(row["Class"]), icon="rocket")
    ).add_to(launch_map)

# Display the map
launch_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_484b7c8477d0fe4b59f070b2939ebaa9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_484b7c8477d0fe4b59f070b2939ebaa9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_484b7c8477d0fe4b59f070b2939ebaa9 = L.map(
#                 &quot;map_484b7c8477d0fe4b59f070b2939ebaa9&quot;,
#                 {
#                     center: [28.57, -80.6],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bf73f8943c46d90a0127c32c8262d844 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bf73f8943c46d90a0127c32c8262d844.addTo(map_484b7c8477d0fe4b59f070b2939ebaa9);
#
#
#             var marker_15665d77304839cb2faef8ac7d92f9e6 = L.marker(
#                 [28.573255, -80.646895],
#                 {
# }
#             ).addTo(map_484b7c8477d0fe4b59f070b2939ebaa9);
#
#
#             var icon_0aa75fcd999e8b9f7d203e5ff9f65c35 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_15665d77304839cb2faef8ac7d92f9e6.setIcon(icon_0aa75fcd999e8b9f7d203e5ff9f65c35);
#
#
#         var popup_47e31f91cd84be78a9898463d93bf0e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f429f467c0ba18458cedf56a05e76bf0 = $(`&lt;div id=&quot;html_f429f467c0ba18458cedf56a05e76bf0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site: KSC LC-39A&lt;br&gt;Outcome: Success&lt;/div&gt;`)[0];
#                 popup_47e31f91cd84be78a9898463d93bf0e2.setContent(html_f429f467c0ba18458cedf56a05e76bf0);
#
#
#
#         marker_15665d77304839cb2faef8ac7d92f9e6.bindPopup(popup_47e31f91cd84be78a9898463d93bf0e2)
#         ;
#
#
#
#
#             var marker_4fac82985d4ae70424cd566495b1ea27 = L.marker(
#                 [28.573255, -80.646895],
#                 {
# }
#             ).addTo(map_484b7c8477d0fe4b59f070b2939ebaa9);
#
#
#             var icon_02dad4244bdd0221495fbe596edf6ec8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_4fac82985d4ae70424cd566495b1ea27.setIcon(icon_02dad4244bdd0221495fbe596edf6ec8);
#
#
#         var popup_c7eec7d6fec6399f6b723822ae2164db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39484e5180884e0a80540e9fa76e7935 = $(`&lt;div id=&quot;html_39484e5180884e0a80540e9fa76e7935&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site: KSC LC-39A&lt;br&gt;Outcome: Success&lt;/div&gt;`)[0];
#                 popup_c7eec7d6fec6399f6b723822ae2164db.setContent(html_39484e5180884e0a80540e9fa76e7935);
#
#
#
#         marker_4fac82985d4ae70424cd566495b1ea27.bindPopup(popup_c7eec7d6fec6399f6b723822ae2164db)
#         ;
#
#
#
#
#             var marker_723ea99700f78aa1b92e4fbf0c4bd7af = L.marker(
#                 [28.573255, -80.646895],
#                 {
# }
#             ).addTo(map_484b7c8477d0fe4b59f070b2939ebaa9);
#
#
#             var icon_dbbdcc4326b3dfd1bc88d50a3a79ff59 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_723ea99700f78aa1b92e4fbf0c4bd7af.setIcon(icon_dbbdcc4326b3dfd1bc88d50a3a79ff59);
#
#
#         var popup_2815267c46a129d29acac2dab0505fe1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_928022b3465113259558bcb7b4ea1a0b = $(`&lt;div id=&quot;html_928022b3465113259558bcb7b4ea1a0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site: KSC LC-39A&lt;br&gt;Outcome: Success&lt;/div&gt;`)[0];
#                 popup_2815267c46a129d29acac2dab0505fe1.setContent(html_928022b3465113259558bcb7b4ea1a0b);
#
#
#
#         marker_723ea99700f78aa1b92e4fbf0c4bd7af.bindPopup(popup_2815267c46a129d29acac2dab0505fe1)
#         ;
#
#
#
#
#             var marker_7c1836200d6c399d1a97eb4a0b1ac7f5 = L.marker(
#                 [28.563197, -80.57682],
#                 {
# }
#             ).addTo(map_484b7c8477d0fe4b59f070b2939ebaa9);
#
#
#             var icon_f464df2fde1bea3e8d29ec96471

# %% [markdown]
# Next, let's try to enhance the map by adding the launch outcomes for each site, and see which sites have high success rates.
# Recall that data frame spacex_df has detailed launch records, and the `class` column indicates if this launch was successful or not

# %%
spacex_df
# Out:
#     Launch Site        Lat       Long  Class
# 0    KSC LC-39A  28.573255 -80.646895      1
# 1    KSC LC-39A  28.573255 -80.646895      1
# 2    KSC LC-39A  28.573255 -80.646895      1
# 3  CCAFS SLC-40  28.563197 -80.576820      1
# 4  CCAFS SLC-40  28.563197 -80.576820      1
# 5  CCAFS SLC-40  28.563197 -80.576820      0
# 6  CCAFS SLC-40  28.563197 -80.576820      0
# 7  CCAFS SLC-40  28.563197 -80.576820      0
# 8  CCAFS SLC-40  28.563197 -80.576820      1
# 9  CCAFS SLC-40  28.563197 -80.576820      0

# %% [markdown]
# Next, let's create markers for all launch records.
# If a launch was successful `(class=1)`, then we use a green marker and if a launch was failed, we use a red marker `(class=0)`

# %% [markdown]
# Note that a launch only happens in one of the four launch sites, which means many launch records will have the exact same coordinate. Marker clusters can be a good way to simplify a map containing many markers having the same coordinate.

# %% [markdown]
# Let's first create a `MarkerCluster` object

# %%
marker_cluster = MarkerCluster()

# %% [markdown]
# *TODO:* Create a new column in `spacex_df` dataframe called `marker_color` to store the marker colors based on the `class` value

# %%
# Apply a function to check the value of `class` column
# If class=1, marker_color value will be green
# If class=0, marker_color value will be red
from folium.plugins import MarkerCluster

# Create a new column 'marker_color' based on the 'Class' column
spacex_df["marker_color"] = spacex_df["Class"].apply(lambda x: "green" if x == 1 else "red")

# Create a Folium map centered around the launch sites
launch_map = folium.Map(location=[28.57, -80.6], zoom_start=6)

# Create a MarkerCluster layer
marker_cluster = MarkerCluster().add_to(launch_map)

# Add clustered markers for each launch with success (green) or failure (red)
for _, row in spacex_df.iterrows():
    folium.Marker(
        location=[row["Lat"], row["Long"]],
        popup=f"Launch Site: {row['Launch Site']}<br>Outcome: {'Success' if row['Class'] == 1 else 'Failure'}",
        icon=folium.Icon(color=row["marker_color"], icon="rocket")
    ).add_to(marker_cluster)

# Display the map
launch_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_69ea2ca5cb6251c26b315ecce1ac73e5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_69ea2ca5cb6251c26b315ecce1ac73e5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_69ea2ca5cb6251c26b315ecce1ac73e5 = L.map(
#                 &quot;map_69ea2ca5cb6251c26b315ecce1ac73e5&quot;,
#                 {
#                     center: [28.57, -80.6],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c343ffc9cf46eab947c020b086eebb0c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c343ffc9cf46eab947c020b086eebb0c.addTo(map_69ea2ca5cb6251c26b315ecce1ac73e5);
#
#
#             var marker_cluster_b42985b9614b6add6b02cc4aa13e3517 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_c814f4c9c8d5af1b34b1a8b4ea018ce0 = L.marker(
#                 [28.573255, -80.646895],
#                 {
# }
#             ).addTo(marker_cluster_b42985b9614b6add6b02cc4aa13e3517);
#
#
#             var icon_bf7b9e1fc93ffcb70113279156aa953e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_c814f4c9c8d5af1b34b1a8b4ea018ce0.setIcon(icon_bf7b9e1fc93ffcb70113279156aa953e);
#
#
#         var popup_3971ebc34a411e63a96d7a202e2375b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1522c34ea3c2233cc120c3845f1f9bdd = $(`&lt;div id=&quot;html_1522c34ea3c2233cc120c3845f1f9bdd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site: KSC LC-39A&lt;br&gt;Outcome: Success&lt;/div&gt;`)[0];
#                 popup_3971ebc34a411e63a96d7a202e2375b8.setContent(html_1522c34ea3c2233cc120c3845f1f9bdd);
#
#
#
#         marker_c814f4c9c8d5af1b34b1a8b4ea018ce0.bindPopup(popup_3971ebc34a411e63a96d7a202e2375b8)
#         ;
#
#
#
#
#             var marker_1f23019d62f7c4d7c975a848b6b16b4d = L.marker(
#                 [28.573255, -80.646895],
#                 {
# }
#             ).addTo(marker_cluster_b42985b9614b6add6b02cc4aa13e3517);
#
#
#             var icon_3dba9fd1dc5aba1836dbb46b2c6ea4e6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_1f23019d62f7c4d7c975a848b6b16b4d.setIcon(icon_3dba9fd1dc5aba1836dbb46b2c6ea4e6);
#
#
#         var popup_e48fbd23ddff04b7c499514a64503752 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d0f378eb569d646e08be1afa397a97f = $(`&lt;div id=&quot;html_3d0f378eb569d646e08be1afa397a97f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site: KSC LC-39A&lt;br&gt;Outcome: Success&lt;/div&gt;`)[0];
#                 popup_e48fbd23ddff04b7c499514a64503752.setContent(html_3d0f378eb569d646e08be1afa397a97f);
#
#
#
#         marker_1f23019d62f7c4d7c975a848b6b16b4d.bindPopup(popup_e48fbd23ddff04b7c499514a64503752)
#         ;
#
#
#
#
#             var marker_14690b9bbd933719a8f024bcbb07dd6e = L.marker(
#                 [28.573255, -80.646895],
#                 {
# }
#             ).addTo(marker_cluster_b42985b9614b6add6b02cc4aa13e3517);
#
#
#             var icon_f7d6fb071e885185d9931ca6c74f5745 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_14690b9bbd933719a8f024bcbb07dd6e.setIcon(icon_f7d6fb071e885185d9931ca6c74f5745);
#
#
#         var popup_37a66bfa550567cbe006f2645056b4e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6e67e9e5fdb8373b2c07b32f6a4e8ab = $(`&lt;div id=&quot;html_d6e67e9e5fdb8373b2c07b32f6a4e8ab&quot; style=&quot;

# %% [markdown]
# *TODO:* For each launch result in `spacex_df` data frame, add a `folium.Marker` to `marker_cluster`

# %%
# Add marker_cluster to current site_map
site_map.add_child(marker_cluster)

# for each row in spacex_df data frame
# create a Marker object with its coordinate
# and customize the Marker's icon property to indicate if this launch was successed or failed, 
# e.g., icon=folium.Icon(color='white', icon_color=row['marker_color']
for index, record in spacex_df.iterrows():
    # TODO: Create and add a Marker cluster to the site map
    # marker = folium.Marker(...)
    marker_cluster.add_child(marker)

site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_abe5f7aadf60c281f4d1a2fbdc76eee1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_abe5f7aadf60c281f4d1a2fbdc76eee1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_abe5f7aadf60c281f4d1a2fbdc76eee1 = L.map(
#                 &quot;map_abe5f7aadf60c281f4d1a2fbdc76eee1&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff681467bb4e5b357fb4dab4a157c4d1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ff681467bb4e5b357fb4dab4a157c4d1.addTo(map_abe5f7aadf60c281f4d1a2fbdc76eee1);
#
#
#             var marker_cluster_b42985b9614b6add6b02cc4aa13e3517 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_c814f4c9c8d5af1b34b1a8b4ea018ce0 = L.marker(
#                 [28.573255, -80.646895],
#                 {
# }
#             ).addTo(marker_cluster_b42985b9614b6add6b02cc4aa13e3517);
#
#
#             var icon_bf7b9e1fc93ffcb70113279156aa953e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_c814f4c9c8d5af1b34b1a8b4ea018ce0.setIcon(icon_bf7b9e1fc93ffcb70113279156aa953e);
#
#
#         var popup_3971ebc34a411e63a96d7a202e2375b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1522c34ea3c2233cc120c3845f1f9bdd = $(`&lt;div id=&quot;html_1522c34ea3c2233cc120c3845f1f9bdd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site: KSC LC-39A&lt;br&gt;Outcome: Success&lt;/div&gt;`)[0];
#                 popup_3971ebc34a411e63a96d7a202e2375b8.setContent(html_1522c34ea3c2233cc120c3845f1f9bdd);
#
#
#
#         marker_c814f4c9c8d5af1b34b1a8b4ea018ce0.bindPopup(popup_3971ebc34a411e63a96d7a202e2375b8)
#         ;
#
#
#
#
#             var marker_1f23019d62f7c4d7c975a848b6b16b4d = L.marker(
#                 [28.573255, -80.646895],
#                 {
# }
#             ).addTo(marker_cluster_b42985b9614b6add6b02cc4aa13e3517);
#
#
#             var icon_3dba9fd1dc5aba1836dbb46b2c6ea4e6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_1f23019d62f7c4d7c975a848b6b16b4d.setIcon(icon_3dba9fd1dc5aba1836dbb46b2c6ea4e6);
#
#
#         var popup_e48fbd23ddff04b7c499514a64503752 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d0f378eb569d646e08be1afa397a97f = $(`&lt;div id=&quot;html_3d0f378eb569d646e08be1afa397a97f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site: KSC LC-39A&lt;br&gt;Outcome: Success&lt;/div&gt;`)[0];
#                 popup_e48fbd23ddff04b7c499514a64503752.setContent(html_3d0f378eb569d646e08be1afa397a97f);
#
#
#
#         marker_1f23019d62f7c4d7c975a848b6b16b4d.bindPopup(popup_e48fbd23ddff04b7c499514a64503752)
#         ;
#
#
#
#
#             var marker_14690b9bbd933719a8f024bcbb07dd6e = L.marker(
#                 [28.573255, -80.646895],
#                 {
# }
#             ).addTo(marker_cluster_b42985b9614b6add6b02cc4aa13e3517);
#
#
#             var icon_f7d6fb071e885185d9931ca6c74f5745 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_14690b9bbd933719a8f024bcbb07dd6e.setIcon(icon_f7d6fb071e885185d9931ca6c74f5745);
#
#
#         var popup_37a66bfa550567cbe006f2645056b4e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6e67e9e5fdb8373b2c07b32f6a4e8ab = $(`&lt;div id=&quot;html_d6e67e9e5fdb8373b2c07b32f6

# %% [markdown]
# Your updated map may look like the following screenshots:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_cluster.png">
# </center>

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_cluster_zoomed.png">
# </center>

# %% [markdown]
# From the color-labeled markers in marker clusters, you should be able to easily identify which launch sites have relatively high success rates.

# %%
# TASK 3: Calculate the distances between a launch site to its proximities
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[34], line 2
#       1 # TASK 3: Calculate the distances between a launch site to its proximities
# ----> 2 from geopy.distance import geodesic
#       4 # Define proximity points (example: road, railway, coastline)
#       5 proximity_points = {
#       6     "Highway": (28.57205, -80.58528),
#       7     "Railway": (28.57212, -80.60704),
#       8     "Coastline": (28.56342, -80.56704)
#       9 }
#
# ModuleNotFoundError: No module named 'geopy'

# %% [markdown]
# Next, we need to explore and analyze the proximities of launch sites.

# %% [markdown]
# Let's first add a `MousePosition` on the map to get coordinate for a mouse over a point on the map. As such, while you are exploring the map, you can easily find the coordinates of any points of interests (such as railway)

# %%
# Add Mouse Position to get the coordinate (Lat, Long) for a mouse over on the map
formatter = "function(num) {return L.Util.formatNum(num, 5);};"
mouse_position = MousePosition(
    position='topright',
    separator=' Long: ',
    empty_string='NaN',
    lng_first=False,
    num_digits=20,
    prefix='Lat:',
    lat_formatter=formatter,
    lng_formatter=formatter,
)

site_map.add_child(mouse_position)
site_map

# %% [markdown]
# Now zoom in to a launch site and explore its proximity to see if you can easily find any railway, highway, coastline, etc. Move your mouse to these points and mark down their coordinates (shown on the top-left) in order to the distance to the launch site.

# %% [markdown]
# Now zoom in to a launch site and explore its proximity to see if you can easily find any railway, highway, coastline, etc. Move your mouse to these points and mark down their coordinates (shown on the top-left) in order to the distance to the launch site.

# %%
from math import sin, cos, sqrt, atan2, radians

def calculate_distance(lat1, lon1, lat2, lon2):
    # approximate radius of earth in km
    R = 6373.0

    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c
    return distance

# %% [markdown]
# *TODO:* Mark down a point on the closest coastline using MousePosition and calculate the distance between the coastline point and the launch site.

# %%
# find coordinate of the closet coastline
# e.g.,: Lat: 28.56367  Lon: -80.57163
# distance_coastline = calculate_distance(launch_site_lat, launch_site_lon, coastline_lat, coastline_lon)

# %%
# Create and add a folium.Marker on your selected closest coastline point on the map
# Display the distance between coastline point and launch site using the icon property 
# for example
# distance_marker = folium.Marker(
#    coordinate,
#    icon=DivIcon(
#        icon_size=(20,20),
#        icon_anchor=(0,0),
#        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance),
#        )
#    )

# %% [markdown]
# *TODO:* Draw a `PolyLine` between a launch site to the selected coastline point

# %%
# Create a `folium.PolyLine` object using the coastline coordinates and launch site coordinate
# lines=folium.PolyLine(locations=coordinates, weight=1)
site_map.add_child(lines)

# %% [markdown]
# Your updated map with distance line should look like the following screenshot:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_distance.png">
# </center>

# %% [markdown]
# *TODO:* Similarly, you can draw a line betwee a launch site to its closest city, railway, highway, etc. You need to use `MousePosition` to find the their coordinates on the map first

# %% [markdown]
# A railway map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/railway.png">
# </center>

# %% [markdown]
# A highway map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/highway.png">
# </center>

# %% [markdown]
# A city map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/city.png">
# </center>

# %%
# Create a marker with distance to a closest city, railway, highway, etc.
# Draw a line between the marker to the launch site

# %% [markdown]
# After you plot distance lines to the proximities, you can answer the following questions easily:
#
# *   Are launch sites in close proximity to railways?
# *   Are launch sites in close proximity to highways?
# *   Are launch sites in close proximity to coastline?
# *   Do launch sites keep certain distance away from cities?
#
# Also please try to explain your findings.

# %% [markdown]
# # Next Steps:
#
# Now you have discovered many interesting insights related to the launch sites' location using folium, in a very interactive way. Next, you will need to build a dashboard using Ploty Dash on detailed launch records.

# %% [markdown]
# ## Authors

# %% [markdown]
# [Pratiksha Verma](https://www.linkedin.com/in/pratiksha-verma-6487561b1/)

# %% [markdown]
# <!--## Change Log--!>

# %% [markdown]
# <!--| Date (YYYY-MM-DD) | Version | Changed By      | Change Description      |
# | ----------------- | ------- | -------------   | ----------------------- |
# | 2022-11-09        | 1.0     | Pratiksha Verma | Converted initial version to Jupyterlite|--!>

# %% [markdown]
# ### <h3 align="center"> IBM Corporation 2022. All rights reserved. <h3/>
